# %% [markdown]
# # Improve Classification of web articles
# In this lab we will improve the performance of our Naive Bayes classifier from the theory learned in class.

# %%
import nltk
from nltk import FreqDist
from nltk.collocations import *
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %% [markdown]
# ## Preprocessing the articles

# %% [markdown]
# Loading the corpus or articles

# %%
#Read the datasets
path = 'C:\\tmp\\'
filePrefix = 'training_'
categories=['ARTS','SPORTS']
dataset={}
dataset_raw = {}
allFeatures=set()
tot_articles = 0
articles_count={}

N={} # Number of articles in each corpus

for category in categories:
    fileName=path+filePrefix+category.lower()
    f=open(fileName,'r')
    text = ''
    text_raw = ''    
    lines=f.readlines()
    tot_articles+=len(lines)
    articles_count[category] = len(lines)
    dataset_raw[category] = list(map(lambda line: line.lower(), lines))
    
    for line in lines:
        text+=line.replace('\n',' ').lower()
        text_raw = line.lower()
    f.close
    N[category]=len(lines)
    
    tokens = nltk.word_tokenize(text)
    dataset[category] = nltk.Text(tokens)

# %% [markdown]
# Removing Punctuations & Stopwording

# %%
dataset_clean={}

def remove_punctuation(corpus):
    punctuations = ".,\"-\\/#!?$%\^&\*;:{}=\-_'~()"    
    filtered_corpus = [token for token in corpus if (not token in punctuations)]
    return filtered_corpus

def apply_stopwording(corpus, min_len):
    filtered_corpus = [token for token in corpus if (not token in stopwords.words('english') and len(token)>min_len)]
    return filtered_corpus

#Let's remove punctuation characters and apply stopwording
for category in categories:
    print 'Processing %s' % category
    dataset_clean[category] = apply_stopwording(remove_punctuation(dataset[category]), 3)
    print dataset_clean[category]
# Out:
# Processing ARTS
# ['excerpts', 'interview', 'rapper', 'kendrick', 'lamar', 'discusses', 'critically', 'acclaimed', 'album', 'pimp', 'butterfly', 'recent', 'grammy', 'nominations', 'york', 'times', 'critics', 'manohla', 'dargis', 'scott', 'stephen', 'holden', 'list', 'picks', 'oscar-worthy', 'films', 'performances', '2015.', 'caramanica', 'profiles', 'blogger', 'stephen', 'carbone', 'posting', 'spoilers', 'reality', 'show', 'bachelor', 'past', 'four', 'years', 'website', 'realitysteve.com', 'reflects', 'show', 'begins', '20th', 'season', 'carbone', 'continues', 'information', 'sources', 'adam', 'mckay', 'director', 'co-writer', 'caper', 'movie', 'short', 'discusses', 'used', 'humor', 'explain', 'complicated', 'aspects', '2008', 'housing', 'banking', 'crisis', 'zachary', 'woolfe', 'offers', 'highlights', 'season', 'amazon', 'original', 'series', 'mozart', 'jungle', 'starring', 'gael', 'garcia', 'bernal', 'show', 'features', 'behind-the-scenes', 'look', 'semi-fictional', 'york', 'symphony', 'orchestra', 'pareles', 'reviews', 'latest', 'albums', 'songwriter', 'miya', 'folick', 'singer', 'ruby', 'amanfu', 'electronic', 'music', 'producer', 'kode9', 'british', 'singer', 'shirley', 'collins', 'xylophonist', 'kakraba', 'manhattan', 'theater', 'club', 'production', 'richard', 'greenberg', 'play', 'mother', 'brief', 'affair', 'open', 'samuel', 'friedman', 'theater', 'brings', 'together', 'theater', 'stalwarts', 'greenberg', 'actress', 'linda', 'lavin', 'director', 'lynne', 'meadow', 'playwright', 'dominique', 'morisseau', 'pays', 'homage', 'hometown', 'detroit', 'play', 'skeleton', 'crew', 'final', 'work', 'prizewinning', 'detroit', 'trilogy', 'drama', 'staged', 'atlantic', 'theater', 'company', '2008', 'focuses', 'workers', 'city', 'last', 'remaining', 'auto', 'plant', 'choreographer', 'annie', 'parson', 'dance', 'concert', 'short', 'form', 'premiere', 'kitchen', 'celebrates', '25th', 'anniversary', 'company', 'dance', 'theater', 'program', 'works', 'feature', 'performances', 'husband', 'paul', 'lazar', 'onstage', 'birthday', 'party', 'intermission', 'wesley', 'morris', 'discusses', 'four', 'worthy', 'movies', '2015', 'likely', 'ignored', 'oscar', 'season', 'list', 'includes', 'creed', 'results', 'woman', 'gold', 'danny', 'collins', 'actress', 'brie', 'larson', 'portrayed', 'woman', 'imprisoned', 'sexual', 'predator', 'movie', 'room', 'midst', 'monthslong', 'press', 'campaign', 'movie', 'awards', 'season', 'already', 'received', 'golden', 'globe', 'nomination', 'could', 'receive', 'leading', 'actress', 'oscar', 'manohla', 'dargis', 'scott', 'discuss', 'field', 'potential', 'oscar', 'nominees', 'reflect', 'blockbusters', 'represented', 'many', '2015', 'best', 'movies', 'charles', 'play', 'glory', 'world', 'opening', 'brooklyn', 'academy', 'music', 'explores', 'life', '20th-century', 'american', 'catholic', 'thinker', 'thomas', 'merton', 'production', 'directed', 'waters', 'financed', 'cockrum', 'former', 'episcopal', 'monk', 'million', '2014', 'lottery', 'snapshot', 'interview', 'playwright', 'lauren', 'gunderson', 'discusses', 'breakthrough', 'play', 'making', 'york', 'debut', '59e59', 'theaters', 'clove', 'galilee', 'directs', 'mabou', 'mines', 'trick', 'saddle', 'production', 'play', 'imagining', 'imaginary', 'invalid', 'inspired', 'moliere', 'comedy', 'imaginary', 'invalid', 'mama', 'show', 'features', 'homage', 'french', 'playwright', 'actress', 'ruth', 'maleczech', 'galilee', 'mother', 'helped', 'conceive', 'starred', 'original', 'workshop', 'production', 'dying', 'cancer', '2013.', 'pareles', 'reviews', 'latest', 'albums', 'producer-singer', 'country', 'singer', 'chris', 'young', 'rapper', 'wiki', 'also', 'reviews', 'books', 'definition', 'life', 'ice-t', 'birth', 'darlene', 'ortiz', 'memoir', 'opinion', 'rapper', 'mall', 'profile', 'in-demand', 'songwriting', 'team', 'julia', 'michaels', 'justin', 'tranter', 'worked', 'newcomers', 'established', 'musical', 'acts', 'craig', 'gillespie', 'film', 'finest', 'hours', 'chronicles', 'real-life', 'story' ...
# Processing SPORTS
# ['closer', 'look', 'rare', 'losses', 'best', 'teams', 'history', 'suggests', 'golden', 'state', 'warriors', 'chances', 'historic', 'season', 'would', 'considerably', 'star', 'point', 'guard', 'stephen', 'curry', 'remains', 'sideline', 'analysis', 'jacksonville', 'jaguars', 'quarterback', 'blake', 'bortles', 'future', 'looks', 'bright', 'despite', 'team', 'current', '5-10', 'record', 'ranks', 'second', 'passing', 'touchdowns', 'behind', 'england', 'patriots', 'quarterback', 'brady', 'sixth', 'passing', 'yards', 'preview', 'week', 'matchups', 'william', 'rhoden', 'sports', 'times', 'column', 'clemson', 'football', 'coach', 'dabo', 'swinney', 'accused', 'creating', 'culture', 'team', 'goes', 'promoting', 'christianity', 'asserts', 'realistic', 'head', 'coaches', 'like', 'swinney', 'know', 'important', 'part', 'games', 'save', 'young', 'souls', 'roundup', 'milwaukee', 'bucks', 'defeat', 'indiana', 'pacers', '120-116', 'basketball', 'scores', 'news', 'noted', 'college', 'basketball', 'roundup', 'villanova', 'college', 'basketball', 'team', 'defeats', 'xavier', '95-64', 'women', 'scores', 'noted', 'boston', 'pride', 'national', 'women', 'hockey', 'league', 'ties', 'canadiennes', 'canadian', 'women', 'hockey', 'league', 'inaugural', 'outdoor', 'women', 'classic', 'gillette', 'stadium', 'pride', 'player', 'denna', 'laing', 'injured', 'losing', 'footing', 'raising', 'concerns', 'conditions', 'questioned', 'earlier', 'university', 'california', 'quarterback', 'jared', 'goff', 'skip', 'senior', 'year', 'enter', '2016', 'draft', 'news', 'noted', 'espn', 'reports', 'viewership', 'college', 'football', 'playoff', 'semifinal', 'games', 'played', 'year', 'dropped', 'drastically', 'compared', 'last', 'season', 'games', 'played', 'year', 'chicago', 'bulls', 'defeat', 'york', 'knicks', '108-81.', 'washington', 'wizards', 'beat', 'orlando', 'magic', '103-91', 'basketball', 'scores', 'noted', 'roundup', 'ohio', 'state', 'defeats', 'notre', 'dame', '44-28', 'fiesta', 'bowl', 'bowl', 'games', 'noted', 'keeping', 'score', 'column', 'notes', 'york', 'knicks', 'continue', 'play', 'slow-paced', 'game', 'despite', 'run-and-gun', 'style', 'golden', 'state', 'warriors', 'fast-breaking', 'teams', 'york', 'giants', 'coach', 'coughlin', 'preparing', 'final', 'game', 'giants', 'head', 'coach', 'held', 'since', '2004.', 'college', 'football', 'roundup', 'texas', 'christian', 'defeats', 'oregon', '47-41', 'alamo', 'bowl', 'bowl', 'games', 'noted', 'roundup', 'jersey', 'devils', 'defeat', 'dallas', 'stars', 'overtime', 'hockey', 'scores', 'noted', 'united', 'states', 'defeats', 'czech', 'republic', 'quarterfinals', 'world', 'junior', 'hockey', 'championship', 'denver', 'broncos', 'defeat', 'diego', 'chargers', '27-20', 'seed', 'seal', 'first-round', 'home', 'field', 'advantage', 'playoffs', 'roundup', 'york', 'islanders', 'defeat', 'dallas', 'stars', 'hockey', 'scores', 'noted', 'york', 'giants', 'fail', 'last', 'game', 'coach', 'coughlin', 'announced', 'retirement', 'could', 'soon', 'leave', 'philadelphia', 'eagles', 'hold', 'give', 'interim', 'coach', 'shurmur', 'first', 'william', 'rhoden', 'sports', 'times', 'column', 'holds', 'york', 'jets', 'season-ending', 'loss', 'buffalo', 'bills', 'revives', 'debate', 'starting', 'quarterback', 'next', 'season', 'notes', '11-year', 'veteran', 'ryan', 'fitzpatrick', 'threw', 'three', 'interceptions', 'looked', 'confused', 'throughout', 'game', 'ford', 'center', 'star', 'dallas', 'cowboys', 'headquarters', 'frisco', 'include', 'training', 'facility', 'practice', 'fields', 'offices', 'indoor', 'stadium', 'shared', 'eight', 'local', 'high', 'schools', 'project', 'also', 'includes', 'entertainment', 'retail', 'district', 'built', 'blue', 'star', 'land', 'development', 'company', 'owned', 'family', 'team', 'owner', 'jerry', 'jones', 'zinedine', 'zidane', 'midfielder', 'france', 'world', 'named', 'head', 'coach', 'real', 'madrid', 'replace', 'rafael', 'benitez', 'limited', 'coaching', 'experience', 'york', 'jets', 'quarterback ...

# %% [markdown]
# Apply Stemming or Lemmatization

# %%
dataset_final={}
all_words=set()

def apply_stemming(corpus):
    stemmer = nltk.PorterStemmer()
    normalized_corpus = [stemmer.stem(token) for token in corpus]
    return normalized_corpus

def apply_lemmatization(corpus):
    lemmatizer = nltk.WordNetLemmatizer()
    normalized_corpus = [lemmatizer.lemmatize(token) for token in corpus]
    return normalized_corpus

for category in categories:
    print 'Processing %s' % category
    dataset_final[category] = apply_stemming(dataset_clean[category])
    print dataset_final[category]
    for token in dataset_final[category]:
        all_words.add(token)
# Out:
# Processing ARTS
# [u'excerpt', u'interview', u'rapper', u'kendrick', u'lamar', u'discuss', u'critic', u'acclaim', u'album', u'pimp', u'butterfli', u'recent', u'grammi', u'nomin', u'york', u'time', u'critic', u'manohla', u'dargi', u'scott', u'stephen', u'holden', u'list', u'pick', u'oscar-worthi', u'film', u'perform', u'2015.', u'caramanica', u'profil', u'blogger', u'stephen', u'carbon', u'post', u'spoiler', u'realiti', u'show', u'bachelor', u'past', u'four', u'year', u'websit', u'realitysteve.com', u'reflect', u'show', u'begin', u'20th', u'season', u'carbon', u'continu', u'inform', u'sourc', u'adam', u'mckay', u'director', u'co-writ', u'caper', u'movi', u'short', u'discuss', u'use', u'humor', u'explain', u'complic', u'aspect', u'2008', u'hous', u'bank', u'crisi', u'zachari', u'woolf', u'offer', u'highlight', u'season', u'amazon', u'origin', u'seri', u'mozart', u'jungl', u'star', u'gael', u'garcia', u'bernal', u'show', u'featur', u'behind-the-scen', u'look', u'semi-fict', u'york', u'symphoni', u'orchestra', u'parel', u'review', u'latest', u'album', u'songwrit', u'miya', u'folick', u'singer', u'rubi', u'amanfu', u'electron', u'music', u'produc', u'kode9', u'british', u'singer', u'shirley', u'collin', u'xylophonist', u'kakraba', u'manhattan', u'theater', u'club', u'product', u'richard', u'greenberg', u'play', u'mother', u'brief', u'affair', u'open', u'samuel', u'friedman', u'theater', u'bring', u'togeth', u'theater', u'stalwart', u'greenberg', u'actress', u'linda', u'lavin', u'director', u'lynn', u'meadow', u'playwright', u'dominiqu', u'morisseau', u'pay', u'homag', u'hometown', u'detroit', u'play', u'skeleton', u'crew', u'final', u'work', u'prizewin', u'detroit', u'trilog', u'drama', u'stage', u'atlant', u'theater', u'compani', u'2008', u'focus', u'worker', u'citi', u'last', u'remain', u'auto', u'plant', u'choreograph', u'anni', u'parson', u'danc', u'concert', u'short', u'form', u'premier', u'kitchen', u'celebr', u'25th', u'anniversari', u'compani', u'danc', u'theater', u'program', u'work', u'featur', u'perform', u'husband', u'paul', u'lazar', u'onstag', u'birthday', u'parti', u'intermiss', u'wesley', u'morri', u'discuss', u'four', u'worthi', u'movi', u'2015', u'like', u'ignor', u'oscar', u'season', u'list', u'includ', u'creed', u'result', u'woman', u'gold', u'danni', u'collin', u'actress', u'brie', u'larson', u'portray', u'woman', u'imprison', u'sexual', u'predat', u'movi', u'room', u'midst', u'monthslong', u'press', u'campaign', u'movi', u'award', u'season', u'alreadi', u'receiv', u'golden', u'globe', u'nomin', u'could', u'receiv', u'lead', u'actress', u'oscar', u'manohla', u'dargi', u'scott', u'discuss', u'field', u'potenti', u'oscar', u'nomine', u'reflect', u'blockbust', u'repres', u'mani', u'2015', u'best', u'movi', u'charl', u'play', u'glori', u'world', u'open', u'brooklyn', u'academi', u'music', u'explor', u'life', u'20th-centuri', u'american', u'cathol', u'thinker', u'thoma', u'merton', u'product', u'direct', u'water', u'financ', u'cockrum', u'former', u'episcop', u'monk', u'million', u'2014', u'lotteri', u'snapshot', u'interview', u'playwright', u'lauren', u'gunderson', u'discuss', u'breakthrough', u'play', u'make', u'york', u'debut', u'59e59', u'theater', u'clove', u'galile', u'direct', u'mabou', u'mine', u'trick', u'saddl', u'product', u'play', u'imagin', u'imaginari', u'invalid', u'inspir', u'molier', u'comedi', u'imaginari', u'invalid', u'mama', u'show', u'featur', u'homag', u'french', u'playwright', u'actress', u'ruth', u'maleczech', u'galile', u'mother', u'help', u'conceiv', u'star', u'origin', u'workshop', u'product', u'die', u'cancer', u'2013.', u'parel', u'review', u'latest', u'album', u'producer-sing', u'countri', u'singer', u'chri', u'young', u'rapper', u'wiki', u'also', u'review', u'book', u'definit', u'life', u'ice-t', u'birth', u'darlen', u'ortiz', u'memoir', u'opinion', u'rapper', u'mall', u'profil', u'in-demand', u'songwrit', u'team', u'julia', u'michael', u'justin', u'tranter', u'work', u'newcom', u'establish', u'music', ...
# Processing SPORTS
# [u'closer', u'look', u'rare', u'loss', u'best', u'team', u'histori', u'suggest', u'golden', u'state', u'warrior', u'chanc', u'histor', u'season', u'would', u'consider', u'star', u'point', u'guard', u'stephen', u'curri', u'remain', u'sidelin', u'analysi', u'jacksonvil', u'jaguar', u'quarterback', u'blake', u'bortl', u'futur', u'look', u'bright', u'despit', u'team', u'current', u'5-10', u'record', u'rank', u'second', u'pass', u'touchdown', u'behind', u'england', u'patriot', u'quarterback', u'bradi', u'sixth', u'pass', u'yard', u'preview', u'week', u'matchup', u'william', u'rhoden', u'sport', u'time', u'column', u'clemson', u'footbal', u'coach', u'dabo', u'swinney', u'accus', u'creat', u'cultur', u'team', u'goe', u'promot', u'christian', u'assert', u'realist', u'head', u'coach', u'like', u'swinney', u'know', u'import', u'part', u'game', u'save', u'young', u'soul', u'roundup', u'milwauke', u'buck', u'defeat', u'indiana', u'pacer', u'120-116', u'basketbal', u'score', u'news', u'note', u'colleg', u'basketbal', u'roundup', u'villanova', u'colleg', u'basketbal', u'team', u'defeat', u'xavier', u'95-64', u'women', u'score', u'note', u'boston', u'pride', u'nation', u'women', u'hockey', u'leagu', u'tie', u'canadienn', u'canadian', u'women', u'hockey', u'leagu', u'inaugur', u'outdoor', u'women', u'classic', u'gillett', u'stadium', u'pride', u'player', u'denna', u'la', u'injur', u'lose', u'foot', u'rais', u'concern', u'condit', u'question', u'earlier', u'univers', u'california', u'quarterback', u'jare', u'goff', u'skip', u'senior', u'year', u'enter', u'2016', u'draft', u'news', u'note', u'espn', u'report', u'viewership', u'colleg', u'footbal', u'playoff', u'semifin', u'game', u'play', u'year', u'drop', u'drastic', u'compar', u'last', u'season', u'game', u'play', u'year', u'chicago', u'bull', u'defeat', u'york', u'knick', u'108-81.', u'washington', u'wizard', u'beat', u'orlando', u'magic', u'103-91', u'basketbal', u'score', u'note', u'roundup', u'ohio', u'state', u'defeat', u'notr', u'dame', u'44-28', u'fiesta', u'bowl', u'bowl', u'game', u'note', u'keep', u'score', u'column', u'note', u'york', u'knick', u'continu', u'play', u'slow-pac', u'game', u'despit', u'run-and-gun', u'style', u'golden', u'state', u'warrior', u'fast-break', u'team', u'york', u'giant', u'coach', u'coughlin', u'prepar', u'final', u'game', u'giant', u'head', u'coach', u'held', u'sinc', u'2004.', u'colleg', u'footbal', u'roundup', u'texa', u'christian', u'defeat', u'oregon', u'47-41', u'alamo', u'bowl', u'bowl', u'game', u'note', u'roundup', u'jersey', u'devil', u'defeat', u'dalla', u'star', u'overtim', u'hockey', u'score', u'note', u'unit', u'state', u'defeat', u'czech', u'republ', u'quarterfin', u'world', u'junior', u'hockey', u'championship', u'denver', u'bronco', u'defeat', u'diego', u'charger', u'27-20', u'seed', u'seal', u'first-round', u'home', u'field', u'advantag', u'playoff', u'roundup', u'york', u'island', u'defeat', u'dalla', u'star', u'hockey', u'score', u'note', u'york', u'giant', u'fail', u'last', u'game', u'coach', u'coughlin', u'announc', u'retir', u'could', u'soon', u'leav', u'philadelphia', u'eagl', u'hold', u'give', u'interim', u'coach', u'shurmur', u'first', u'william', u'rhoden', u'sport', u'time', u'column', u'hold', u'york', u'jet', u'season-end', u'loss', u'buffalo', u'bill', u'reviv', u'debat', u'start', u'quarterback', u'next', u'season', u'note', u'11-year', u'veteran', u'ryan', u'fitzpatrick', u'threw', u'three', u'intercept', u'look', u'confus', u'throughout', u'game', u'ford', u'center', u'star', u'dalla', u'cowboy', u'headquart', u'frisco', u'includ', u'train', u'facil', u'practic', u'field', u'offic', u'indoor', u'stadium', u'share', u'eight', u'local', u'high', u'school', u'project', u'also', u'includ', u'entertain', u'retail', u'district', u'built', u'blue', u'star', u'land', u'develop', u'compani', u'own', u'famili', u'team', u'owner', u'jerri', u'jone', u'zinedin', u'zidan', u'midfield', u'franc', u'world', u'name', u'head', u'coach', u ...

# %% [markdown]
# Define all functions needed for the implementation of the Naive Bayes classifier (see "Classifying Web Articles Notebook")

# %%
feature_count = {}
category_count = {}
probCat = {}

# Calculate the probabilities for each category
for category in categories:
    probCat[category]=articles_count[category]*1.0/tot_articles
    print ("%s - p(%s)=%s" % (category,category,probCat[category]))
# Out:
# ARTS - p(ARTS)=0.5
# SPORTS - p(SPORTS)=0.5

# %%
freqWord = {}
wordCounts = {}

def buildFrequencies(dataset):
    for category in categories:
        freqWord[category] = FreqDist(dataset[category])
        wordCounts[category] = len(dataset[category])


#Generate frequencies: the implementation is very different from the first version
buildFrequencies(dataset_final)

print ("Checking Frequencies for word 'team':")
print ("F('team'|'ARTS')=%s" % freqWord['ARTS']['team'])
print ("F('team'|'SPORTS')=%s" % freqWord['SPORTS']['team'])
# Out:
# Checking Frequencies for word 'team':
# F('team'|'ARTS')=2
# F('team'|'SPORTS')=25

# %%
def getTermProbability(word):
    count = 0
    total = 0
    for category in categories:
        total += wordCounts[category]
        if word in freqWord[category]:
            count+=freqWord[category][word]
    return count*1.0/total

def getTermCondProbability(word,category):
    count = 0
    total = wordCounts[category]

    if word in freqWord[category]:
        count=freqWord[category][word]
    else:
        #Apply Laplace Smoothing
        count=1.0/(len(freqWord[category])+len(allFeatures))
    
    return count*1.0/total
    
print ("probability for word 'actress' - p('actress')=%s" % getTermProbability('actress'))
print ("probability for word 'actress' in ARTS - p('actress'|'ARTS')=%s" % getTermCondProbability('actress','ARTS'))
print ("probability for word 'actress' in SPORTS - p('actress'|'SPORTS')=%s" % getTermCondProbability('actress','SPORTS'))
# Out:
# probability for word 'actress' - p('actress')=0.00296256396445
# probability for word 'actress' in ARTS - p('actress'|'ARTS')=0.00559227249619
# probability for word 'actress' in SPORTS - p('actress'|'SPORTS')=6.47893310113e-07

# %%
def NaiveBayesClassifier(article):
    words = [w for w in word_tokenize(article)]
    results={}
    for category in categories:
        pCat = probCat[category]
        pNumerator = 1.0
        for word in words:
            pN = getTermCondProbability(word,category)
            pNumerator*= pN
            #print '[%s] p(%s)=%s' % (category, word,pN)

        pClassification = pNumerator*pCat
        results[category] = pClassification
        #print '[%s] p()=%s' % (category, pClassification)
    
    pMax = 0.0
    predictedClass = ''
    for category in categories:
        if results[category]>pMax:
            pMax = results[category]
            predictedClass = category

    #print ('The article has been assigned to class "%s" with a probability of %s' % (predictedClass,pMax))
    return predictedClass

# %% [markdown]
# Testing the Classifier

# %%
def get_string_from_corpus(corpus):
    result=''
    for token in corpus:
        result+=token
        result+=' '
    return result[:-1]

f=open('C:\\tmp\\testing.txt','r')
lines=f.readlines()
f.close

correct = 0
total = len(lines)
index = 1

TP=0.0
TN=0.0
FP=0.0
FN=0.0

F=0.0
precision = 0.0
recall = 0.0

test_articles = {}

for line in lines:
    elems = line.split('\t')
    article=elems[0]
    category=elems[1][:-1]
    
    #Clean up the article and apply normalization
    text = nltk.Text(nltk.word_tokenize(article.decode('utf-8').lower()))
    clean_article = get_string_from_corpus(apply_stemming(apply_stopwording(remove_punctuation(text), 3)))
    test_articles[clean_article]=category
    
    predictedCategory = NaiveBayesClassifier(str(clean_article))
    
    print '%s. Prediction[%s] Class[%s]' % (index,predictedCategory,category)
    index+=1
    
    #Calculating quality measures
    if (predictedCategory == category):
        correct+=1
        if (category == categories[1]):
            TP+=1
        else:
            TN+=1
    else:
        if (predictedCategory == categories[1]):
            FN+=1
        else:
            FP+=1

precision = TP/(TP+FP)
recall = TP/(TP+FN)
F=2*(precision*recall)/(precision+recall)

print ('\nThe classifer was correct %s out of %s or %s' % (correct,total,correct*1.0/total))
print 'precision=%s' % precision
print 'recall=%s' % recall
print 'F=%s' % F
# Out:
# 1. Prediction[SPORTS] Class[SPORTS]
# 2. Prediction[SPORTS] Class[SPORTS]
# 3. Prediction[ARTS] Class[SPORTS]
# 4. Prediction[SPORTS] Class[SPORTS]
# 5. Prediction[SPORTS] Class[SPORTS]
# 6. Prediction[SPORTS] Class[ARTS]
# 7. Prediction[ARTS] Class[ARTS]
# 8. Prediction[ARTS] Class[ARTS]
# 9. Prediction[SPORTS] Class[ARTS]
# 10. Prediction[SPORTS] Class[ARTS]
#
# The classifer was correct 6 out of 10 or 0.6
# precision=0.8
# recall=0.571428571429
# F=0.666666666667

# %% [markdown]
# ## Comparing our results with the NLTK Naive Bayes Classifier

# %% [markdown]
# The input for the NLTK Naive Bayes Classifier is slightly different from what we used before and it is in the form of [(featureset,label)], with the featureset a dictionary and label is our category.

# %%
import collections

def get_featureset(corpus):
    dict=collections.defaultdict(list)
    result = []
    for category in categories:
        result.extend([({token:(token in dataset_final[category]) for token in all_words}, category)])
    return result

inputset = get_featureset(dataset_final)
print inputset
# Out:
# [({u'bad-boy': True, u'four': True, u'skeleton': True, u'whose': True, u'accus': False, u'reshuffl': False, u'sorri': False, u'ilya': True, u'edward': False, u'pride': False, u'void': True, u'rise': True, u'voic': True, u'tenni': False, u'govern': True, u'senil': True, u'school': True, u'tangerin': True, u'krakowski': True, u'reinvent': True, u'xylophonist': True, u'triumph': True, u'miller': False, u'direct': True, u'second': False, u'street': True, u'blue': False, u'aim': True, u'asif': True, u'introspect': True, u'orchestra': True, u'filmmak': True, u'net': False, u'maverick': False, u'specialist': True, u'henrik': False, u'met': False, u'studio': True, u'point-of-view': True, u'path': True, u'coen': True, u'tomsula': False, u'112-120': False, u'songwrit': True, u'jame': True, u'flyer': False, u'darlen': True, u'controversi': True, u'golden': True, u'119-113': False, u'campaign': True, u'newspap': False, u'julia': True, u'brought': False, u'madoff': True, u'unit': False, u'highli': True, u'plot': True, u'symphoni': True, u'describ': True, u'would': False, u'program': True, u'music': True, u'recommend': True, u'indiana': False, u'preview': False, u'showrunn': True, u'oscar': True, u'relat': False, u'award': True, u'warn': False, u'berlin': True, u'midst': True, u'hold': False, u'must': False, u'1991': True, u'1990': True, u'join': False, u'room': True, u'henri': True, u'work': True, u'hansen': True, u'root': True, u'fitzpatrick': False, u'give': False, u'bennett': True, u'indic': False, u'want': True, u'basebal': False, u'goff': False, u'keep': True, u'end': True, u'thing': True, u'travel': False, u'108-81.': False, u'revisit': True, u'interview': True, u'disappoint': False, u'widespread': False, u'2015.': True, u'perspect': True, u'stefani': True, u'little-seen': True, u'averag': False, u'shurmur': False, u'domin': True, u'third': False, u'perform': True, u'danni': True, u'green': False, u'south': True, u'incorpor': True, u'enter': False, u'wing': False, u'egger': True, u'oper': False, u'composit': True, u'offici': False, u'murray': False, u'pascal': True, u'flexibl': True, u'hip-hop': True, u'denver': False, u'crew': True, u'better': True, u'offic': False, u'anim': True, u'cornerback': False, u'promin': True, u'disturb': True, u'break': True, u'band': True, u'promis': True, u'bank': True, u'wenn': True, u'victori': False, u'debut': True, u'ii-era': True, u'detroit': True, u'lockout': True, u'bond': True, u'tony-nomin': True, u'zutrau': True, u'lifter': False, u'commiss': True, u'contend': True, u'network': True, u'goe': False, u'daniel': True, u'adapt': True, u'postseason': False, u'mccarthi': False, u'arizona': False, u'barrier': False, u'free': False, u'baseman': False, u'angi': True, u'major-confer': False, u'loui': False, u'bankrol': True, u'confus': False, u'playwright': True, u'95-64': False, u'independ': False, u'20th-centuri': True, u'rank': False, u'alreadi': True, u'nomin': True, u'fiction': True, u'master': True, u'draft': False, u'hollywood': True, u'john': True, u'5-10': False, u'spoiler': True, u'erickson': True, u'hors': False, u'final': True, u'project': True, u'hayn': True, u'third-round': False, u'holden': True, u'acclaim': True, u'boston': True, u'guggenheim': True, u'ram': False, u'mind': True, u'mine': True, u'seed': False, u'mabou': True, u'octob': True, u'seek': True, u'dozen': True, u'1968': False, u'luxuri': False, u'1964': False, u'1967': False, u'brandon': True, u'thoma': True, u'quarterback': False, u'even': True, u'memorabilia': True, u'marin': False, u'offstag': True, u'buzzfe': False, u'maria': False, u'tradit': True, u'singer': True, u'off-broadway': True, u'cathol': True, u'flow': True, u'carolin': True, u'bateman': True, u'takahata': True, u'synaps': True, u'dupe': False, u'radio': True, u'big-screen': False, u'sexism': False, u'caper': True, u'despit': False, u'best-sel': True, u'explain': True, u'103-91': False, u'knoxvil': True, u'restaur': True, u'theme': True, u'busi': False, u'tenpen ...

# %% [markdown]
# Train the NLTK Naive Bayes Classifier

# %% [markdown]
# for the format look at http://stackoverflow.com/questions/20827741/nltk-naivebayesclassifier-training-for-sentiment-analysis

# %%
from nltk.classify import NaiveBayesClassifier
nb_classifier = NaiveBayesClassifier.train(inputset)
nb_classifier.labels()
nb_classifier.show_most_informative_features()
# Out:
# Most Informative Features

# %% [markdown]
# Classify our testset

# %%
index=1
for article in test_articles.keys():
    testset = {token: (token in article) for token in all_words}
    predictedCategory = nb_classifier.classify(testset)
    print '%s. Prediction[%s] Class[%s]' % (index,predictedCategory,test_articles[article])
    index+=1
# Out:
# 1. Prediction[SPORTS] Class[ARTS]
# 2. Prediction[SPORTS] Class[SPORTS]
# 3. Prediction[SPORTS] Class[SPORTS]
# 4. Prediction[SPORTS] Class[ARTS]
# 5. Prediction[SPORTS] Class[SPORTS]
# 6. Prediction[SPORTS] Class[ARTS]
# 7. Prediction[SPORTS] Class[ARTS]
# 8. Prediction[SPORTS] Class[ARTS]
# 9. Prediction[SPORTS] Class[SPORTS]
# 10. Prediction[SPORTS] Class[SPORTS]

# %% [markdown]
# Our Classifier does a much better job!
